# %%
import matplotlib.pyplot as plt

x = [0, 0, -1, 1, 0, -2, 2, 0] # Puntos en x
y = [10, 8, 7, 7, 4, 3, 3, 0] #Puntos en y

plt.scatter(x, y, label="Cohete")  #Graficamos los puntos

plt.xlabel("x") # Coredanadas x
plt.ylabel("y") #Cordenadas en y
plt.title("Cohete") #Titulo del cohete
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 0, -1, 1, 0, -2, 2, 0] # Puntos en x
y = [10, 8, 7, 7, 4, 3, 3, 0] #Puntos en y

plt.scatter(x, y, label="Cohete")  #Graficamos los puntos

plt.xlabel("x") # Coredanadas x
plt.ylabel("y") #Cordenadas en y
plt.title("Cohete") #Titulo del cohete
plt.legend()
plt.show()

theta=np.radians(55)
matriz_rotacion=np.array([np.cos(theta)]), -np.sin(theta), [np.sin(theta)], np.cos(theta)])
imagen_rotacion = np.dot(matriz_rotacion, np.array([x,y]))

print ()

plt.scatter(imagen_rotacion{0}, imagen_rotacion [1], label0"rotacion", marker="x")
plt.show()
# Out:
#   File "<ipython-input-21-09df77b1b249>", line 15
#     matriz_rotacion=np.array([np.cos(theta)]), -np.sin(theta), [np.sin(theta)], np.cos(theta)])
#                                                                                              ^
# SyntaxError: unmatched ']'
